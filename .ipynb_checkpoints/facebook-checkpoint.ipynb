# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# import statsmodels.formula.api as smf


sns.set(rc={'figure.figsize': (8,8)})
sns.set_style('dark')

fb = pd.read_csv('DATA/dataset_Facebook.csv', delimiter=";")

# %%
fb.shape
# Out:
# (500, 19)

# %%
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 500 entries, 0 to 499
# Data columns (total 19 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     500 non-null    int64
#  1   Type                                                                 500 non-null    object
#  2   Category                                                             500 non-null    int64
#  3   Post Month                                                           500 non-null    int64
#  4   Post Weekday                                                         500 non-null    int64
#  5   Post Hour                                                            500 non-null    int64
#  6   Paid                                                                 499 non-null    float64
# ...

# %%
fb['Post_Month'] = fb['Post Month'].astype('category')

# %%
fb['Post_Weekday'] = fb['Post Weekday'].astype('category')

# %%
fb.Post_Weekday.head(10)
# Out:
# 0    4
# 1    3
# 2    3
# 3    2
# 4    2
# 5    1
# 6    1
# 7    7
# 8    7
# 9    6
# Name: Post_Weekday, dtype: category
# Categories (7, int64): [1, 2, 3, 4, 5, 6, 7]

# %%
fb.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
fb.head()
# Out:
#    Page total likes    Type  Category  Post Month  Post Weekday  Post Hour  \
# 0            139441   Photo         2          12             4          3
# 1            139441  Status         2          12             3         10
# 2            139441   Photo         3          12             3          3
# 3            139441   Photo         2          12             2         10
# 4            139441   Photo         2          12             2          3
#
#    Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0   0.0                       2752                             5091
# 1   0.0                      10460                            19057
# 2   0.0                       2413                             4373
# 3   1.0                      50128                            87991
# 4   0.0                       7244                            13594
#
#    Lifetime Engaged Users  ...  Lifetime Post Consumptions  \
# ...

# %%
fb.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions', 'Post_Month',
#        'Post_Weekday'],
#       dtype='object')

# %%
fb.tail(10)
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 490             85979  Photo         3           1             6         11
# 491             85979  Photo         3           1             6          3
# 492             85979   Link         1           1             5         11
# 493             85093  Photo         3           1             1          2
# 494             85093  Photo         3           1             7         10
# 495             85093  Photo         3           1             7          2
# 496             81370  Photo         2           1             5          8
# 497             81370  Photo         1           1             5          2
# 498             81370  Photo         3           1             4         11
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# ...

# %%
fb[fb.Paid.isna()]
# Out:
#      Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 499             81370  Photo         2           1             4          4
#
#      Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 499   NaN                       4188                             7292
#
#      Lifetime Engaged Users  ...  Lifetime Post Consumptions  \
# 499                     564  ...                         743
#
#      Lifetime Post Impressions by people who have liked your Page  \
# 499                                               3861
#
#      Lifetime Post reach by people who like your Page  \
# 499                                              2200
#
#      Lifetime People who have liked your Page and engaged with your post  \
# 499                                                316
#
#      comment  like  share  Total Interactions  Post_Month Post_Weekday
# 499        0  91.0   28.0                 119           1            4
#
# [1 rows x 21 columns]

# %%
fb = fb[fb.share.notna()]
fb = fb[fb.Paid.notna()]
fb = fb[fb.like.notna()]

# %%
fb.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 495 entries, 0 to 498
# Data columns (total 21 columns):
#  #   Column                                                               Non-Null Count  Dtype
# ---  ------                                                               --------------  -----
#  0   Page total likes                                                     495 non-null    int64
#  1   Type                                                                 495 non-null    object
#  2   Category                                                             495 non-null    int64
#  3   Post Month                                                           495 non-null    int64
#  4   Post Weekday                                                         495 non-null    int64
#  5   Post Hour                                                            495 non-null    int64
#  6   Paid                                                                 495 non-null    float64
# ...

# %%
fb.Type.unique()
# Out:
# array(['Photo', 'Status', 'Link', 'Video'], dtype=object)

# %%
photos = fb[fb.Type=='Photo']
photos.head(10)
# Out:
#     Page total likes   Type  Category  Post Month  Post Weekday  Post Hour  \
# 0             139441  Photo         2          12             4          3
# 2             139441  Photo         3          12             3          3
# 3             139441  Photo         2          12             2         10
# 4             139441  Photo         2          12             2          3
# 6             139441  Photo         3          12             1          3
# 7             139441  Photo         3          12             7          9
# 9             139441  Photo         3          12             6         10
# 11            139441  Photo         2          12             5         10
# 12            139441  Photo         2          12             5         10
# 13            139441  Photo         2          12             5          3
#
#     Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# 0    0.0                       2752                             5091
# ...

# %%
# videos = fb[fb.Type=='Video']
# links = fb[fb.Type=='Link']

# %%
fb.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions', 'Post_Month',
#        'Post_Weekday'],
#       dtype='object')

# %% [markdown]
# - avg likes? by post Month? day? hour?
# - avg shares?
# - count lifetime post total reach?
# - page total likes?
# - avg likes?
# - lifetime engaged users?

# %%
sns.relplot(x='Post Month', y='Lifetime Post Total Impressions', data=fb)

# %%
sns.scatterplot(x='Post Hour',y='like',data = fb, hue = "Type" )

# %%
sns.relplot(x="Post Weekday", y="like", kind="line", data=fb, ci=None)

# %%
sns.relplot(x="Post Weekday", y="Lifetime Post Total Reach", kind="line", data=fb, ci=None)

# %%
sns.catplot(x="Post Weekday", y="like", jitter=False, data=fb)

# %%
sns.catplot(x="Post Month", kind="count", data=fb, color=None);

# %%
fb.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions', 'Post_Month',
#        'Post_Weekday'],
#       dtype='object')

# %%
sns.catplot(data=fb, orient="h", kind="box");
# Out:
# /Users/luima/miniconda3/lib/python3.7/site-packages/seaborn/axisgrid.py:856: UserWarning: Tight layout not applied. The left and right margins cannot be made large enough to accommodate all axes decorations.
#   self.fig.tight_layout()

# %%
fb['Lifetime Post Total Reach'].values
# Out:
# array([  2752,  10460,   2413,  50128,   7244,  10472,  11692,  13720,
#         11844,   4694,  21744,   3112,   2847,   2549,  22784,  10060,
#          1722,  53264,   3930,   1591,   2848,   1384,   3454,   2723,
#          8488,   8284,  19552,   2478,   9560,  36208,   4940,   1683,
#          5280,   3002,   3766,   4512,   2690,  19800,  17576,   3290,
#         13280,  18480,   7268,   2645,   4284,   7968,  16576,   1925,
#          3786,   1536,   1728,  25248,   4894,   2935,   2425,  16416,
#          5812,   2545,   2257,  27072,  10940,  50912,  28752,  27216,
#          2352,   3416,   2149,  53456,   2168,   3102,  39344, 100768,
#          9056,  11444,  13544,  37376,   1228,  22984,   1445,   3754,
#          8728,   5990,   4582,   2938,   6692,   2566,  21176,   4012,
#          1531,   2938,  24720,   2219,   4732,   2225,   2626,   3090,
#          1101,   2819,  12468,  12776,   1357,  68896,   1711,   1388,
# ...

# %%
fb.describe()
# Out:
#        Page total likes    Category  Post Month  Post Weekday   Post Hour  \
# count        500.000000  500.000000  500.000000    500.000000  500.000000
# mean      123194.176000    1.880000    7.038000      4.150000    7.840000
# std        16272.813214    0.852675    3.307936      2.030701    4.368589
# min        81370.000000    1.000000    1.000000      1.000000    1.000000
# 25%       112676.000000    1.000000    4.000000      2.000000    3.000000
# 50%       129600.000000    2.000000    7.000000      4.000000    9.000000
# 75%       136393.000000    3.000000   10.000000      6.000000   11.000000
# max       139441.000000    3.000000   12.000000      7.000000   23.000000
#
#              Paid  Lifetime Post Total Reach  Lifetime Post Total Impressions  \
# count  499.000000                  500.00000                     5.000000e+02
# mean     0.278557                13903.36000                     2.958595e+04
# ...

# %%
fb.like.mean()
# Out:
# 179.14545454545456

# %%
sns.lmplot(x='like',y='Paid', data=fb, ci=False)

# %%
sns.set(context='notebook', style='dark', rc={'figure.figsize': (16,3)})

sns.boxplot(x='Page total likes', data=fb, color='#2AA5FF')

# %%
fb.columns
# Out:
# Index(['Page total likes', 'Type', 'Category', 'Post Month', 'Post Weekday',
#        'Post Hour', 'Paid', 'Lifetime Post Total Reach',
#        'Lifetime Post Total Impressions', 'Lifetime Engaged Users',
#        'Lifetime Post Consumers', 'Lifetime Post Consumptions',
#        'Lifetime Post Impressions by people who have liked your Page',
#        'Lifetime Post reach by people who like your Page',
#        'Lifetime People who have liked your Page and engaged with your post',
#        'comment', 'like', 'share', 'Total Interactions', 'Post_Month',
#        'Post_Weekday'],
#       dtype='object')

# %%
mean = fb['like'].mean()
mean
sns.distplot(fb['like'].values)
plt.axvline(mean,0, 1, color = 'red')

# %%
sns.distplot(fb['Total Interactions'])

# %%
# sns.scatterplot(x='Lifetime Post reach by people who like your Page', y='Total Interactions', data=fb)
# sns.scatterplot(x='Lifetime Post Total Reach', y='Total Interactions', data=fb)
sns.scatterplot(x='Lifetime People who have liked your Page and engaged with your post', y='Total Interactions', data=fb)

# %%
sns.scatterplot(x = 'Post Weekday', y = 'share', data = fb)
